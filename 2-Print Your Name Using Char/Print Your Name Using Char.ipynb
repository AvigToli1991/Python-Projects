# %%
def print_big(name , ch):
    
    while len(ch) > 1:
        ch = input("Wrong input! Choose a single char. Enter char : ")
        
    dic = {'a' : f'  {ch}  \n {ch} {ch} \n{ch*5}\n{ch}   {ch}\n{ch}   {ch}' ,
           'b' : f'{ch*4} \n{ch}   {ch}\n{ch*4} \n{ch}   {ch}\n{ch*4} ' ,
           'c' : f' {ch*3} \n{ch}   {ch}\n{ch}    \n{ch}   {ch}\n {ch*3} ' ,
           'd' : f'{ch*4} \n{ch}   {ch}\n{ch}   {ch}\n{ch}   {ch}\n{ch*4} ' ,
           'e' : f'{ch*5}\n{ch}    \n{ch*5}\n{ch}    \n{ch*5}' ,
           'f' : f'{ch*5}\n{ch}    \n{ch*5}\n{ch}    \n{ch}    ' ,
           'g' : f'{ch*4} \n{ch}    \n{ch} {ch*3}\n{ch}  {ch} \n{ch*4} ' ,
           'h' : f'{ch}   {ch}\n{ch}   {ch}\n{ch*5}\n{ch}   {ch}\n{ch}   {ch}' ,
           'i' : f' {ch*3} \n  {ch}  \n  {ch}  \n  {ch}  \n {ch*3} ' ,
           'j' : f' {ch*3} \n  {ch}  \n  {ch}  \n{ch} {ch}  \n {ch*2}  ' ,
           'k' : f'{ch}   {ch}\n{ch}  {ch} \n{ch*3}  \n{ch}  {ch} \n{ch}   {ch}' ,
           'l' : f'{ch}    \n{ch}    \n{ch}    \n{ch}    \n{ch*5}' ,
           'm' : f'{ch}   {ch}\n{ch*2} {ch*2}\n{ch} {ch} {ch}\n{ch}   {ch}\n{ch}   {ch}' ,
           'n' : f'{ch}   {ch}\n{ch*2}  {ch}\n{ch} {ch} {ch}\n{ch}  {ch*2}\n{ch}   {ch}' ,
           'o' : f' {ch*3} \n{ch}   {ch}\n{ch}   {ch}\n{ch}   {ch}\n {ch*3} ' ,
           'p' : f'{ch*4} \n{ch}   {ch}\n{ch*4} \n{ch}    \n{ch}    ' ,
           'q' : f'  {ch}  \n {ch} {ch} \n {ch*3} \n {ch} {ch} \n  {ch} {ch}' ,
           'r' : f'{ch*4} \n{ch}   {ch}\n{ch*4} \n{ch}   {ch}\n{ch}   {ch}' ,
           's' : f' {ch*4}\n{ch}    \n {ch*3} \n    {ch}\n{ch*4} ' ,
           't' : f'{ch*5}\n  {ch}  \n  {ch}  \n  {ch}  \n  {ch}  ' ,
           'u' : f'{ch}   {ch}\n{ch}   {ch}\n{ch}   {ch}\n{ch}   {ch}\n {ch*3} ' ,
           'v' : f'{ch}   {ch}\n{ch}   {ch}\n{ch}   {ch}\n {ch} {ch} \n  {ch}  ' ,
           'w' : f'{ch}   {ch}\n{ch}   {ch}\n{ch} {ch} {ch}\n{ch*2} {ch*2}\n{ch}   {ch}' ,
           'x' : f'{ch}   {ch}\n {ch} {ch} \n  {ch}  \n {ch} {ch} \n{ch}   {ch}' ,
           'y' : f'{ch}   {ch}\n{ch}   {ch}\n {ch} {ch} \n  {ch}  \n  {ch}  ' ,
           'z' : f'{ch*5}\n {ch}   \n  {ch}  \n   {ch} \n{ch*5}'  }
    print("\n\n") 
    for sub_name in name.split():
        my_name = [char for char in sub_name]
        for i in range(5):
            for char in my_name:
                charList = dic[char.lower()].split('\n')
                print(charList[i],end = ' ')
            print()
        print("\n\n")  

print_big(input("Enter Your Name: ") , input("Enter char: "))
# Out:
# Enter Your Name:  Avigdor tolidano is a python programmer
# Enter char:  !#!
# Wrong input! Choose a single char. Enter char :  @
#   @   @   @  @@@  @@@@  @@@@   @@@  @@@@
#  @ @  @   @   @   @     @   @ @   @ @   @
# @@@@@ @   @   @   @ @@@ @   @ @   @ @@@@
# @   @  @ @    @   @  @  @   @ @   @ @   @
# @   @   @    @@@  @@@@  @@@@   @@@  @   @
#
#
#
# @@@@@  @@@  @      @@@  @@@@    @   @   @  @@@
#   @   @   @ @       @   @   @  @ @  @@  @ @   @
#   @   @   @ @       @   @   @ @@@@@ @ @ @ @   @
#   @   @   @ @       @   @   @ @   @ @  @@ @   @
#   @    @@@  @@@@@  @@@  @@@@  @   @ @   @  @@@
#
#
#
#  @@@   @@@@
#   @   @
#   @    @@@
#   @       @
#  @@@  @@@@
#
#
#
#   @
#  @ @
# @@@@@
# @   @
# @   @
#
#
#
# @@@@  @   @ @@@@@ @   @  @@@  @   @
# @   @ @   @   @   @   @ @   @ @@  @
# @@@@   @ @    @   @@@@@ @   @ @ @ @
# @       @     @   @   @ @   @ @  @@
# @       @     @   @   @  @@@  @   @
#
#
#
# @@@@  @@@@   @@@  @@@@  @@@@    @   @   @ @   @ @@@@@ @@@@
# ...
